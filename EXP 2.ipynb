# %%
age=[20,21,22,20,20,21,22,20,21,22]

# %%
print(age)
# Out:
# [20, 21, 22, 20, 20, 21, 22, 20, 21, 22]

# %%
age
# Out:
# [20, 21, 22, 20, 20, 21, 22, 20, 21, 22]

# %%
import statistics

# %%
a=statistics.mean(age)

# %%
a
# Out:
# 20.9

# %%
b=statistics.median(age)

# %%
b
# Out:
# 21.0

# %%
c=statistics.mode(age)

# %%
c
# Out:
# 20

# %%
import numpy as np
x=np.array([1,2,3,4,5,6,6,2,3,1])

# %%
x
# Out:
# array([1, 2, 3, 4, 5, 6, 6, 2, 3, 1])

# %%
print(np.mean(x))
# Out:
# 3.3

# %%
print(np.median(x))
# Out:
# 3.0

# %%
from scipy import stats

# %%
print(stats.mode(x))
# Out:
# ModeResult(mode=np.int64(1), count=np.int64(2))

# %%
print(np.std(x))
# Out:
# 1.7916472867168918

# %%
print(np.var(x))
# Out:
# 3.21
