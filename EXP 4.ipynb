# %%
#import pandas library
import pandas as pd

# %%
#Creating Data Frame
df=pd.DataFrame([[10,12,14,16,19],[11,14,18,19,20],[20,25,26,27,23]],
columns=["CD","DBMS","DSS","CAO","DM" ])

# %%
df
# Out:
#    CD  DBMS  DSS  CAO  DM
# 0  10    12   14   16  19
# 1  11    14   18   19  20
# 2  20    25   26   27  23

# %%
df.shape
# Out:
# (3, 5)

# %%
df.size
# Out:
# 15

# %%
df.ndim
# Out:
# 2

# %%
df2=pd.DataFrame([[5,6,7,8,9]],
 columns=["CD","DBMS","DSS","CAO","DM"])

# %%
df.loc[len(df)]=[5,6,7,8,9]

# %%
df
# Out:
#    CD  DBMS  DSS  CAO  DM
# 0  10    12   14   16  19
# 1  11    14   18   19  20
# 2  20    25   26   27  23
# 3   5     6    7    8   9

# %%
df4=df3.drop(index=[1])

# %%
df4
# Out:
#    CD  DBMS  DSS  CAO  DM
# 0   5     6    7    8   9

# %%
#Finding mean of DSS
print("Mean of DSS:",df4["DSS"].mean())
# Out:
# Mean of DSS: 7.0

# %%
#Finding median of DSS
print("Median of DSS:",df4["DSS"].median())
# Out:
# Median of DSS: 7.0

# %%
#Finding mode of DSS
print("Mode of DSS:",df4["DSS"].mode())
# Out:
# Mode of DSS: 0    7
# Name: DSS, dtype: int64

# %%
# Creating name list
Name=["Aastha","Divya","Ziya"]
Name
# Out:
# ['Aastha', 'Divya', 'Ziya']

# %%
#Creating a Series
Roll_list=pd.Series(Name,index=[1,2,3,])
print(Roll_list)
# Out:
# 1    Aastha
# 2     Divya
# 3      Ziya
# dtype: object
